# %% [markdown]
# ## Setup

# %%
import pandas as pd
import json
import pathlib
from typing import List

# %% [markdown]
# - [/] Title and abstract
#
# - [/] Document classification codes
#
# - [/] Date of publication
#
# - [/] Affiliations
#
# - [/] Citations / references
#     - [/] Cited by count
#     - [/] Reference count
#     - [/] References
#
# - [/] Keywords

# %%
def get(data: dict, path: str | List[str]):
    if type(path) is not list:
        path = path.split(".")
    for property in path:
        if type(data) is not dict or property not in data:
            return None
        data = data[property]
    return data

# %%
def ensure_list_data(x):
    return x if isinstance(x, list) else [x]

# %% [markdown]
# ## Reading data

# %%
df = pd.read_csv('data/processed/merged.csv', index_col=0)

# %%
df["publish_date"] = pd.to_datetime(df["publish_date"])

# %%
list_columns = df.loc[:, ['classification_codes', 'affiliations', 'references', 'keywords']]
list_columns = list_columns.apply(ensure_list_data)

# %%
df
# Out:
#                        id                                              title  \
# 0      2-s2.0-85052201238  Parametric study of hydrogen production via so...
# 1      2-s2.0-85053455291  The phenotypic and mutational spectrum of Thai...
# 2      2-s2.0-85058878790  PH Variation as a Simple and Selective Pathway...
# 3      2-s2.0-85061895439  Classification of advertisement text on Facebo...
# 4      2-s2.0-85059290811  Search for Leptoquarks Coupled to Third-Genera...
# ...                   ...                                                ...
# 20211  2-s2.0-85139854052  Breastfeeding duration is associated with high...
# 20212  2-s2.0-85135838525  Effects of ethylenediaminetetraacetic acid on ...
# 20213  2-s2.0-85130889675  Factors associated with dental caries experien...
# 20214  2-s2.0-85121759166  Preparation, optimization using a mixture desi...
# 20215  2-s2.0-85118465399  Design of robust hierarchical control for homo...
#
#                                      publication_name  \
# 0                        Chemical Engineering Science
# 1                                                Gene
# 2                                            Langmuir
# 3      ACM International Conference Proceeding Series
# 4                             Physical Review Letters
# ...                                               ...
# 20211                    Maternal and Child Nutrition
# 20212                      Journal of Dental Sciences
# 20213                       Special Care in Dentistry
# 20214    Journal of Dispersion Science and Technology
# 20215                International Journal of Control
#
#                                                 abstract publish_date  \
# 0      © 2018 Elsevier LtdComputational fluid dynamic...   2018-12-31
# 1      © 2018 Elsevier B.V.Ornithine transcarbamylase...   2018-12-30
# 2      © 2018 American Chemical Society. The fabricat...   2018-12-26
# 3      © 2018 Association for Computing Machinery.Und...   2018-12-21
# 4      © 2018 CERN.for the CMS Collaboration. Publish...   2018-12-12
# ...                                                  ...          ...
# 20211  © 2022 The Authors. Maternal & Child Nutrition...   2023-01-01
# 20212  © 2022 Association for Dental Sciences of the ...   2023-01-01
# 20213  © 2022 Special Care Dentistry Association and ...   2023-01-01
# 20214  © 2021 Taylor & Francis Group, LLC.This resear...   2023-01-01
# 20215  © 2021 Informa UK Limited, trading as Taylor &...   2023-01-01
#
#        cited_by_count  reference_count  \
# 0                21.0             42.0
# 1                13.0             20.0
# 2                 3.0             36.0
# 3                 0.0             11.0
# 4                51.0            101.0
# ...               ...              ...
# 20211             0.0             44.0
# 20212             0.0             18.0
# 20213             0.0             44.0
# 20214             1.0             47.0
# 20215             1.0             23.0
#
#                                     classification_codes  \
# 0      [{'@_fa': 'true', '$': 'Chemistry (all)', '@co...
# 1      [{'@_fa': 'true', '$': 'Genetics', '@code': '1...
# 2      [{'@_fa': 'true', '$': 'Materials Science (all...
# 3      [{'@_fa': 'true', '$': 'Software', '@code': '1...
# 4      [{'@_fa': 'true', '$': 'Physics and Astronomy ...
# ...                                                  ...
# 20211  [{'@_fa': 'true', '$': 'Pediatrics, Perinatolo...
# 20212  [{'@_fa': 'true', '$': 'Dentistry (all)', '@co...
# 20213  [{'@_fa': 'true', '$': 'Dentistry (all)', '@co...
# 20214  [{'@_fa': 'true', '$': 'Surfaces, Coatings and...
# 20215  [{'@_fa': 'true', '$': 'Control and Systems En...
#
#                                             affiliations  \
# 0      {'affiliation-city': 'Bangkok', '@id': '600281...
# 1      [{'affiliation-city': 'Bangkok', '@id': '60028...
# 2      {'affiliation-city': 'Bangkok', '@id': '600281...
# 3      {'affiliation-city': 'Bangkok', '@id': '600281...
# 4      [{'affiliation-city': 'Aachen', '@id': '600166...
# ...                                                  ...
# 20211  [{'affiliation-city': 'Bangkok', '@id': '60002...
# 20212  [{'affiliation-city': 'Bangkok', '@id': '60028...
# 20213  [{'affiliation-city': 'Pathum Thani', '@id': '...
# 20214  {'affiliation-city': 'Bangkok', '@id': '600281...
# 20215  [{'affiliation-city': 'Bangkok', '@id': '60028...
#
#                                               references  \
# 0      [{'ref-fulltext': 'Abanades, J.C., Anthony, E....
# 1      [{'ref-fulltext': 'Brassier, A., Gobin, S., Ar...
# 2      [{'ref-fulltext': 'Chronopoulou, L.; Fratoddi,...
# 3      [{'ref-fulltext': 'S. Leesa-nguansuk. Thailand...
# 4      [{'ref-fulltext': 'J. P. Lees (BABAR Collabora...
# ...                                                  ...
# 20211  [{'ref-fulltext': 'Aris, I. M., Bernard, J. Y....
# 20212  [{'ref-fulltext': 'Ong, T.K., Lim, G.S., Singh...
# 20213  [{'ref-fulltext': 'Jones MW, Morgan E, Shelton...
# 20214  [{'ref-fulltext': 'Higuera-Ciapara, I.; Félix-...
# 20215  [{'ref-fulltext': 'Boyd, S., Ghaoui, L. E., Fe...
#
#                                                 keywords
# 0      [{'@_fa': 'true', '$': 'Circulating fluidized ...
# 1      [{'@_fa': 'true', '$': 'Female'}, {'@_fa': 'tr...
# 2                                                    NaN
# 3      [{'@_fa': 'true', '$': 'AISAS model'}, {'@_fa'...
# 4                                                    NaN
# ...                                                  ...
# 20211  [{'@_fa': 'true', '$': 'adiposity'}, {'@_fa': ...
# 20212  [{'@_fa': 'true', '$': 'Cell apoptosis'}, {'@_...
# 20213  [{'@_fa': 'true', '$': 'carbohydrate snack'}, ...
# 20214  [{'@_fa': 'true', '$': 'Astaxanthin'}, {'@_fa'...
# 20215  [{'@_fa': 'true', '$': 'disturbance attenuatio...
#
# [20216 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20216 entries, 0 to 20215
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    20216 non-null  object
#  1   title                 20215 non-null  object
#  2   publication_name      20216 non-null  object
#  3   abstract              19551 non-null  object
#  4   publish_date          20216 non-null  datetime64[ns]
#  5   cited_by_count        20212 non-null  float64
#  6   reference_count       19805 non-null  float64
#  7   classification_codes  20216 non-null  object
#  8   affiliations          20216 non-null  object
#  9   references            19805 non-null  object
#  10  keywords              16454 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(8)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Tables

# %% [markdown]
# ### Papers

# %%
papers_df = df.drop(columns=['classification_codes', 'affiliations', 'references', 'keywords'])
papers_df
# Out:
#                        id                                              title  \
# 0      2-s2.0-85052201238  Parametric study of hydrogen production via so...
# 1      2-s2.0-85053455291  The phenotypic and mutational spectrum of Thai...
# 2      2-s2.0-85058878790  PH Variation as a Simple and Selective Pathway...
# 3      2-s2.0-85061895439  Classification of advertisement text on Facebo...
# 4      2-s2.0-85059290811  Search for Leptoquarks Coupled to Third-Genera...
# ...                   ...                                                ...
# 20211  2-s2.0-85139854052  Breastfeeding duration is associated with high...
# 20212  2-s2.0-85135838525  Effects of ethylenediaminetetraacetic acid on ...
# 20213  2-s2.0-85130889675  Factors associated with dental caries experien...
# 20214  2-s2.0-85121759166  Preparation, optimization using a mixture desi...
# 20215  2-s2.0-85118465399  Design of robust hierarchical control for homo...
#
#                                      publication_name  \
# 0                        Chemical Engineering Science
# 1                                                Gene
# 2                                            Langmuir
# 3      ACM International Conference Proceeding Series
# 4                             Physical Review Letters
# ...                                               ...
# 20211                    Maternal and Child Nutrition
# 20212                      Journal of Dental Sciences
# 20213                       Special Care in Dentistry
# 20214    Journal of Dispersion Science and Technology
# 20215                International Journal of Control
#
#                                                 abstract publish_date  \
# 0      © 2018 Elsevier LtdComputational fluid dynamic...   2018-12-31
# 1      © 2018 Elsevier B.V.Ornithine transcarbamylase...   2018-12-30
# 2      © 2018 American Chemical Society. The fabricat...   2018-12-26
# 3      © 2018 Association for Computing Machinery.Und...   2018-12-21
# 4      © 2018 CERN.for the CMS Collaboration. Publish...   2018-12-12
# ...                                                  ...          ...
# 20211  © 2022 The Authors. Maternal & Child Nutrition...   2023-01-01
# 20212  © 2022 Association for Dental Sciences of the ...   2023-01-01
# 20213  © 2022 Special Care Dentistry Association and ...   2023-01-01
# 20214  © 2021 Taylor & Francis Group, LLC.This resear...   2023-01-01
# 20215  © 2021 Informa UK Limited, trading as Taylor &...   2023-01-01
#
#        cited_by_count  reference_count
# 0                21.0             42.0
# 1                13.0             20.0
# 2                 3.0             36.0
# 3                 0.0             11.0
# 4                51.0            101.0
# ...               ...              ...
# 20211             0.0             44.0
# 20212             0.0             18.0
# 20213             0.0             44.0
# 20214             1.0             47.0
# 20215             1.0             23.0
#
# [20216 rows x 7 columns]

# %% [markdown]
# ### Classification codes

# %%
classification_codes_df = df.explode('classification_codes', ignore_index=True)[['id', 'classification_codes']]
classification_codes_df.rename(columns={
    'id': 'paper_id',
    'classification_codes': 'classification_code'
}, inplace=True)
classification_codes_df
# Out:
#                  paper_id                                classification_code
# 0      2-s2.0-85052201238  [{'@_fa': 'true', '$': 'Chemistry (all)', '@co...
# 1      2-s2.0-85053455291  [{'@_fa': 'true', '$': 'Genetics', '@code': '1...
# 2      2-s2.0-85058878790  [{'@_fa': 'true', '$': 'Materials Science (all...
# 3      2-s2.0-85061895439  [{'@_fa': 'true', '$': 'Software', '@code': '1...
# 4      2-s2.0-85059290811  [{'@_fa': 'true', '$': 'Physics and Astronomy ...
# ...                   ...                                                ...
# 20211  2-s2.0-85139854052  [{'@_fa': 'true', '$': 'Pediatrics, Perinatolo...
# 20212  2-s2.0-85135838525  [{'@_fa': 'true', '$': 'Dentistry (all)', '@co...
# 20213  2-s2.0-85130889675  [{'@_fa': 'true', '$': 'Dentistry (all)', '@co...
# 20214  2-s2.0-85121759166  [{'@_fa': 'true', '$': 'Surfaces, Coatings and...
# 20215  2-s2.0-85118465399  [{'@_fa': 'true', '$': 'Control and Systems En...
#
# [20216 rows x 2 columns]

# %%
classification_codes_df = classification_codes_df[['paper_id']].join(pd.json_normalize(classification_codes_df['classification_code']))
classification_codes_df
# Out:
#                  paper_id
# 0      2-s2.0-85052201238
# 1      2-s2.0-85053455291
# 2      2-s2.0-85058878790
# 3      2-s2.0-85061895439
# 4      2-s2.0-85059290811
# ...                   ...
# 20211  2-s2.0-85139854052
# 20212  2-s2.0-85135838525
# 20213  2-s2.0-85130889675
# 20214  2-s2.0-85121759166
# 20215  2-s2.0-85118465399
#
# [20216 rows x 1 columns]

# %%
classification_codes_df.drop(columns=['@_fa'], inplace=True)
classification_codes_df
# Out:
#                 paper_id                                          $ @code  \
# 0     2-s2.0-85058392278                    Environmental Chemistry  2304
# 1     2-s2.0-85058392278                 Chemical Engineering (all)  1500
# 2     2-s2.0-85058392278                    Materials Science (all)  2500
# 3     2-s2.0-85058392278                               Energy (all)  2100
# 4     2-s2.0-85059476683                Physics and Astronomy (all)  3100
# ...                  ...                                        ...   ...
# 2480  2-s2.0-85139791256        Arts and Humanities (miscellaneous)  1201
# 2481  2-s2.0-85139245926  Pediatrics, Perinatology and Child Health  2735
# 2482  2-s2.0-85139245926           Anesthesiology and Pain Medicine  2703
# 2483  2-s2.0-85138187650                               Food Science  1106
# 2484  2-s2.0-85119492522                        Otorhinolaryngology  2733
#
#      @abbrev
# 0       ENVI
# 1       CENG
# 2       MATE
# 3       ENER
# 4       PHYS
# ...      ...
# 2480    ARTS
# 2481    MEDI
# 2482    MEDI
# 2483    AGRI
# 2484    MEDI
#
# [2485 rows x 4 columns]

# %%
classification_codes_df.rename(columns={
    '$': 'name',
    '@code': 'code',
    '@abbrev': 'abbreviation'
}, inplace=True)
classification_codes_df
# Out:
#                 paper_id                                       name  code  \
# 0     2-s2.0-85058392278                    Environmental Chemistry  2304
# 1     2-s2.0-85058392278                 Chemical Engineering (all)  1500
# 2     2-s2.0-85058392278                    Materials Science (all)  2500
# 3     2-s2.0-85058392278                               Energy (all)  2100
# 4     2-s2.0-85059476683                Physics and Astronomy (all)  3100
# ...                  ...                                        ...   ...
# 2480  2-s2.0-85139791256        Arts and Humanities (miscellaneous)  1201
# 2481  2-s2.0-85139245926  Pediatrics, Perinatology and Child Health  2735
# 2482  2-s2.0-85139245926           Anesthesiology and Pain Medicine  2703
# 2483  2-s2.0-85138187650                               Food Science  1106
# 2484  2-s2.0-85119492522                        Otorhinolaryngology  2733
#
#      abbreviation
# 0            ENVI
# 1            CENG
# 2            MATE
# 3            ENER
# 4            PHYS
# ...           ...
# 2480         ARTS
# 2481         MEDI
# 2482         MEDI
# 2483         AGRI
# 2484         MEDI
#
# [2485 rows x 4 columns]

# %%
paper_to_classification_code_df = classification_codes_df.loc[:, ['paper_id', 'code']]
paper_to_classification_code_df
# Out:
#                 paper_id  code
# 0     2-s2.0-85058392278  2304
# 1     2-s2.0-85058392278  1500
# 2     2-s2.0-85058392278  2500
# 3     2-s2.0-85058392278  2100
# 4     2-s2.0-85059476683  3100
# ...                  ...   ...
# 2480  2-s2.0-85139791256  1201
# 2481  2-s2.0-85139245926  2735
# 2482  2-s2.0-85139245926  2703
# 2483  2-s2.0-85138187650  1106
# 2484  2-s2.0-85119492522  2733
#
# [2485 rows x 2 columns]

# %%
classification_codes_df.drop(columns=['paper_id'], inplace=True)
classification_codes_df
# Out:
#                                            name  code abbreviation
# 0                       Environmental Chemistry  2304         ENVI
# 1                    Chemical Engineering (all)  1500         CENG
# 2                       Materials Science (all)  2500         MATE
# 3                                  Energy (all)  2100         ENER
# 4                   Physics and Astronomy (all)  3100         PHYS
# ...                                         ...   ...          ...
# 2480        Arts and Humanities (miscellaneous)  1201         ARTS
# 2481  Pediatrics, Perinatology and Child Health  2735         MEDI
# 2482           Anesthesiology and Pain Medicine  2703         MEDI
# 2483                               Food Science  1106         AGRI
# 2484                        Otorhinolaryngology  2733         MEDI
#
# [2485 rows x 3 columns]

# %% [markdown]
# ### Affiliations

# %%
affiliations_df = df.explode('affiliations', ignore_index=True)[['id', 'affiliations']]
affiliations_df.rename(columns={
    'id': 'paper_id',
    'affiliations': 'affiliation'
}, inplace=True)
affiliations_df
# Out:
#                  paper_id                                        affiliation
# 0      2-s2.0-85058392278  {'affiliation-city': 'Rayong', '@id': '6011078...
# 1      2-s2.0-85058392278  {'affiliation-city': 'Bangkok', '@id': '600915...
# 2      2-s2.0-85058392278  {'affiliation-city': 'Arica', '@id': '60030782...
# 3      2-s2.0-85058392278  {'affiliation-city': 'Qinhuangdao', '@id': '60...
# 4      2-s2.0-85059476683  {'affiliation-city': 'Bangkok', '@id': '600281...
# ...                   ...                                                ...
# 12625  2-s2.0-85138187650  {'affiliation-city': 'Mumbai', '@id': '6001415...
# 12626  2-s2.0-85138187650  {'affiliation-city': 'Hangzhou', '@id': '60003...
# 12627  2-s2.0-85119492522  {'affiliation-city': 'Bangkok', '@id': '600221...
# 12628  2-s2.0-85119492522  {'affiliation-city': 'London', '@id': '6001132...
# 12629  2-s2.0-85119492522  {'affiliation-city': 'Bangkok', '@id': '600026...
#
# [12630 rows x 2 columns]

# %%
affiliations_df = affiliations_df[["paper_id"]].join(pd.json_normalize(affiliations_df['affiliation']))
affiliations_df
# Out:
#                  paper_id affiliation-city       @id  \
# 0      2-s2.0-85058392278           Rayong  60110787
# 1      2-s2.0-85058392278          Bangkok  60091507
# 2      2-s2.0-85058392278            Arica  60030782
# 3      2-s2.0-85058392278      Qinhuangdao  60018465
# 4      2-s2.0-85059476683          Bangkok  60028190
# ...                   ...              ...       ...
# 12625  2-s2.0-85138187650           Mumbai  60014153
# 12626  2-s2.0-85138187650         Hangzhou  60003970
# 12627  2-s2.0-85119492522          Bangkok  60022183
# 12628  2-s2.0-85119492522           London  60011326
# 12629  2-s2.0-85119492522          Bangkok  60002620
#
#                                                affilname  \
# 0      Vidyasirimedhi Institute of Science and Techno...
# 1      Metallurgy and Materials Research Institute Ch...
# 2                                Universidad de Tarapacá
# 3                                     Yanshan University
# 4                               Chulalongkorn University
# ...                                                  ...
# 12625              Indian Institute of Technology Bombay
# 12626                                Zhejiang University
# 12627               King Chulalongkorn Memorial Hospital
# 12628                                  UCL Ear Institute
# 12629      Faculty of Medicine, Chulalongkorn University
#
#                                                    @href affiliation-country
# 0      https://api.elsevier.com/content/affiliation/a...            Thailand
# 1      https://api.elsevier.com/content/affiliation/a...            Thailand
# 2      https://api.elsevier.com/content/affiliation/a...               Chile
# 3      https://api.elsevier.com/content/affiliation/a...               China
# 4      https://api.elsevier.com/content/affiliation/a...            Thailand
# ...                                                  ...                 ...
# 12625  https://api.elsevier.com/content/affiliation/a...               India
# 12626  https://api.elsevier.com/content/affiliation/a...               China
# 12627  https://api.elsevier.com/content/affiliation/a...            Thailand
# 12628  https://api.elsevier.com/content/affiliation/a...      United Kingdom
# 12629  https://api.elsevier.com/content/affiliation/a...            Thailand
#
# [12630 rows x 6 columns]

# %%
paper_to_affiliations_df = affiliations_df.loc[:, ['paper_id', '@id']]
paper_to_affiliations_df.rename(columns={
    '@id': 'affiliation_id'
}, inplace=True)
paper_to_affiliations_df
# Out:
#                  paper_id affiliation_id
# 0      2-s2.0-85058392278       60110787
# 1      2-s2.0-85058392278       60091507
# 2      2-s2.0-85058392278       60030782
# 3      2-s2.0-85058392278       60018465
# 4      2-s2.0-85059476683       60028190
# ...                   ...            ...
# 12625  2-s2.0-85138187650       60014153
# 12626  2-s2.0-85138187650       60003970
# 12627  2-s2.0-85119492522       60022183
# 12628  2-s2.0-85119492522       60011326
# 12629  2-s2.0-85119492522       60002620
#
# [12630 rows x 2 columns]

# %%
affiliations_df = affiliations_df.drop(columns=['paper_id']).drop_duplicates().reset_index(drop=True)
affiliations_df
# Out:
#      affiliation-city        @id  \
# 0              Rayong   60110787
# 1             Bangkok   60091507
# 2               Arica   60030782
# 3         Qinhuangdao   60018465
# 4             Bangkok   60028190
# ...               ...        ...
# 1946         Shanghai   60112527
# 1947        Fortaleza   60015440
# 1948          Bangkok  126790845
# 1949         Chetumal   60276903
# 1950           London   60011326
#
#                                               affilname  \
# 0     Vidyasirimedhi Institute of Science and Techno...
# 1     Metallurgy and Materials Research Institute Ch...
# 2                               Universidad de Tarapacá
# 3                                    Yanshan University
# 4                              Chulalongkorn University
# ...                                                 ...
# 1946                                College of Sciences
# 1947                          Universidade de Fortaleza
# 1948                                 Academy of Science
# 1949                      El Colegio de la Frontera Sur
# 1950                                  UCL Ear Institute
#
#                                                   @href affiliation-country
# 0     https://api.elsevier.com/content/affiliation/a...            Thailand
# 1     https://api.elsevier.com/content/affiliation/a...            Thailand
# 2     https://api.elsevier.com/content/affiliation/a...               Chile
# 3     https://api.elsevier.com/content/affiliation/a...               China
# 4     https://api.elsevier.com/content/affiliation/a...            Thailand
# ...                                                 ...                 ...
# 1946  https://api.elsevier.com/content/affiliation/a...               China
# 1947  https://api.elsevier.com/content/affiliation/a...              Brazil
# 1948  https://api.elsevier.com/content/affiliation/a...            Thailand
# 1949  https://api.elsevier.com/content/affiliation/a...              Mexico
# 1950  https://api.elsevier.com/content/affiliation/a...      United Kingdom
#
# [1951 rows x 5 columns]

# %% [markdown]
# ### References

# %%
references_df = df.explode('references', ignore_index=True)[['id', 'references']]
references_df.rename(columns={
    'id': 'paper_id',
    'references': 'reference'
}, inplace=True)
references_df
# Out:
#                  paper_id                                          reference
# 0      2-s2.0-85058392278  {'ref-fulltext': 'T. Inoue, A. Fujishima, S. K...
# 1      2-s2.0-85058392278  {'ref-fulltext': 'S. N. Frank, A. J. Bard, J. ...
# 2      2-s2.0-85058392278  {'ref-fulltext': 'S. A. Grinshpun, A. Adhikari...
# 3      2-s2.0-85058392278  {'ref-fulltext': 'C. Wei, W. Y. Lin, Z. Zainal...
# 4      2-s2.0-85058392278  {'ref-fulltext': 'S. In, A. Orlov, R. Berg, F....
# ...                   ...                                                ...
# 45386  2-s2.0-85119492522  {'ref-fulltext': 'Yanilmaz, M., Akduman, D., S...
# 45387  2-s2.0-85119492522  {'ref-fulltext': 'Yildirim, M.A., Karlidag, T....
# 45388  2-s2.0-85119492522  {'ref-fulltext': 'Karlidag, T., Yildiz, M., Ya...
# 45389  2-s2.0-85119492522  {'ref-fulltext': 'Xiong, Y., Rabchevsky, A.G.,...
# 45390  2-s2.0-85119492522  {'ref-fulltext': 'Liu, B., Gao, H.M., Wang, J....
#
# [45391 rows x 2 columns]

# %%
references_df[references_df['paper_id'] == '2-s2.0-85106046890']
# Out:
# Empty DataFrame
# Columns: [paper_id, reference]
# Index: []

# %%
references_df = references_df.join(pd.json_normalize(references_df["reference"])).drop(columns=['reference'])
references_df
# Out:
#                  paper_id                                       ref-fulltext  \
# 0      2-s2.0-85058392278  T. Inoue, A. Fujishima, S. Konishi, K. Honda, ...
# 1      2-s2.0-85058392278  S. N. Frank, A. J. Bard, J. Am. Chem. Soc. 197...
# 2      2-s2.0-85058392278  S. A. Grinshpun, A. Adhikari, T. Honda, K. Y. ...
# 3      2-s2.0-85058392278  C. Wei, W. Y. Lin, Z. Zainal, N. E. Williams, ...
# 4      2-s2.0-85058392278  S. In, A. Orlov, R. Berg, F. García, S. Pedros...
# ...                   ...                                                ...
# 45386  2-s2.0-85119492522  Yanilmaz, M., Akduman, D., Sagun, ÖF., Hakseve...
# 45387  2-s2.0-85119492522  Yildirim, M.A., Karlidag, T., Akpolat, N., Kay...
# 45388  2-s2.0-85119492522  Karlidag, T., Yildiz, M., Yalcin, S., Colakogl...
# 45389  2-s2.0-85119492522  Xiong, Y., Rabchevsky, A.G., Hall, E.D., Role ...
# 45390  2-s2.0-85119492522  Liu, B., Gao, H.M., Wang, J.Y., Jeohn, G.H., C...
#
#       @id ref-info.ref-publicationyear.@first  \
# 0       1                                1979
# 1       2                                1977
# 2       3                                2007
# 3       4                                1994
# 4       5                                2007
# ...    ..                                 ...
# 45386  29                                2015
# 45387  30                                2015
# 45388  31                                2012
# 45389  32                                2007
# 45390  33                                2002
#
#                          ref-info.refd-itemidlist.itemid  \
# 0      [{'$': 'cssc201802284-cit-0001', '@idtype': 'F...
# 1      [{'$': 'cssc201802284-cit-0002', '@idtype': 'F...
# 2      [{'$': 'cssc201802284-cit-0003', '@idtype': 'F...
# 3      [{'$': 'cssc201802284-cit-0004', '@idtype': 'F...
# 4      [{'$': 'cssc201802284-cit-0005', '@idtype': 'F...
# ...                                                  ...
# 45386  [{'$': 'bib0145', '@idtype': 'FRAGMENTID'}, {'...
# 45387  [{'$': 'bib0150', '@idtype': 'FRAGMENTID'}, {'...
# 45388  [{'$': 'bib0155', '@idtype': 'FRAGMENTID'}, {'...
# 45389  [{'$': 'bib0160', '@idtype': 'FRAGMENTID'}, {'...
# 45390  [{'$': 'bib0165', '@idtype': 'FRAGMENTID'}, {'...
#
#       ref-info.ref-volisspag.voliss.@volume  \
# 0                                       277
# 1                                        99
# 2                                        41
# 3                                        28
# 4                                       129
# ...                                     ...
# 45386                                    26
# 45387                                    26
# 45388                                    39
# 45389                                   100
# 45390                                   962
#
#       ref-info.ref-volisspag.pagerange.@first  \
# 0                                         637
# 1                                         303
# 2                                         606
# 3                                         934
# 4                                       13790
# ...                                       ...
# 45386                                     667
# 45387                                     810
# 45388                                     145
# 45389                                     639
# 45390                                     318
#
#                              ref-info.ref-authors.author  \
# 0      [{'@seq': '1', 'ce:initials': 'T.', '@_fa': 't...
# 1      [{'@seq': '1', 'ce:initials': 'S.N.', '@_fa': ...
# 2      [{'@seq': '1', 'ce:initials': 'S.A.', '@_fa': ...
# 3      [{'@seq': '1', 'ce:initials': 'C.', '@_fa': 't...
# 4      [{'@seq': '1', 'ce:initials': 'S.', '@_fa': 't...
# ...                                                  ...
# 45386  [{'@seq': '1', 'ce:initials': 'M.', '@_fa': 't...
# 45387  [{'@seq': '1', 'ce:initials': 'M.A.', '@_fa': ...
# 45388  [{'@seq': '1', 'ce:initials': 'T.', '@_fa': 't...
# 45389  [{'@seq': '1', 'ce:initials': 'Y.', '@_fa': 't...
# 45390  [{'@seq': '1', 'ce:initials': 'B.', '@_fa': 't...
#
#       ref-info.ref-sourcetitle ref-info.ref-volisspag.pagerange.@last  ...  \
# 0                       Nature                                    NaN  ...
# 1            J. Am. Chem. Soc.                                    304  ...
# 2       Environ. Sci. Technol.                                    612  ...
# 3       Environ. Sci. Technol.                                    938  ...
# 4            J. Am. Chem. Soc.                                  13791  ...
# ...                        ...                                    ...  ...
# 45386        J Craniofac Surg.                                    672  ...
# 45387        J Craniofac Surg.                                    815  ...
# 45388      Auris Nasus Larynx.                                    150  ...
# 45389             J Neurochem.                                    649  ...
# 45390        Ann N Y Acad Sci.                                    331  ...
#
#       ref-info.ref-authors.et-al @aii:was-generated-by @reference-instance-id  \
# 0                            NaN                   NaN                    NaN
# 1                            NaN                   NaN                    NaN
# 2                            NaN                   NaN                    NaN
# 3                            NaN                   NaN                    NaN
# 4                            NaN                   NaN                    NaN
# ...                          ...                   ...                    ...
# 45386                        NaN                   NaN                    NaN
# 45387                        NaN                   NaN                    NaN
# 45388                        NaN                   NaN                    NaN
# 45389                        NaN                   NaN                    NaN
# 45390                        NaN                   NaN                    NaN
#
#       ref-info.ref-volisspag.pages ref-info.ref-publicationyear.@last  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ...                            ...                                ...
# 45386                          NaN                                NaN
# 45387                          NaN                                NaN
# 45388                          NaN                                NaN
# 45389                          NaN                                NaN
# 45390                          NaN                                NaN
#
#       ref-info.ref-website.websitename @date-locked  \
# 0                                  NaN          NaN
# 1                                  NaN          NaN
# 2                                  NaN          NaN
# 3                                  NaN          NaN
# 4                                  NaN          NaN
# ...                                ...          ...
# 45386                              NaN          NaN
# 45387                              NaN          NaN
# 45388                              NaN          NaN
# 45389                              NaN          NaN
# 45390                              NaN          NaN
#
#       ref-info.ref-authors.collaboration ref-info.ref-volisspag.pagecount.$  \
# 0                                    NaN                                NaN
# 1                                    NaN                                NaN
# 2                                    NaN                                NaN
# 3                                    NaN                                NaN
# 4                                    NaN                                NaN
# ...                                  ...                                ...
# 45386                                NaN                                NaN
# 45387                                NaN                                NaN
# 45388                                NaN                                NaN
# 45389                                NaN                                NaN
# 45390                                NaN                                NaN
#
#       ref-info.ref-volisspag.pagecount.@type
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 45386                                    NaN
# 45387                                    NaN
# 45388                                    NaN
# 45389                                    NaN
# 45390                                    NaN
#
# [45391 rows x 31 columns]

# %%
references_df[references_df['ref-info.ref-title.ref-titletext'] == 'What is the Impact of International Remittances on Poverty and Inequality in Latin America?']
# Out:
# Empty DataFrame
# Columns: [paper_id, ref-fulltext, @id, ref-info.ref-publicationyear.@first, ref-info.refd-itemidlist.itemid, ref-info.ref-volisspag.voliss.@volume, ref-info.ref-volisspag.pagerange.@first, ref-info.ref-authors.author, ref-info.ref-sourcetitle, ref-info.ref-volisspag.pagerange.@last, ref-info.ref-website.ce:e-address.$, ref-info.ref-website.ce:e-address.@type, ref-info.refd-itemidlist.itemid.$, ref-info.refd-itemidlist.itemid.@idtype, ref-info.ref-volisspag.voliss.@issue, ref-info.ref-text, ref-info.ref-title.ref-titletext, ce:source-text, ref-info.ref-authors.collaboration.@seq, ref-info.ref-authors.collaboration.ce:text, ref-info.ref-authors.collaboration.ce:indexed-name, ref-info.ref-authors.et-al, @aii:was-generated-by, @reference-instance-id, ref-info.ref-volisspag.pages, ref-info.ref-publicationyear.@last, ref-info.ref-website.websitename, @date-locked, ref-info.ref-authors.collaboration, ref-info.ref-volisspag.pagecount.$, ref-info.ref-volisspag.pagecount.@type]
# Index: []
#
# [0 rows x 31 columns]

# %%
references_df['ref-fulltext'].value_counts()
# Out:
# ref-fulltext
# CMS collaboration, The CMS trigger system, 2017 JINST 12 P01020 [arXiv:1609.02366] [INSPIRE].                                                                                                                                                                                                                                                                                    11
# CMS collaboration, Event generator tunes obtained from underlying event and multiparton scattering measurements, Eur. Phys. J. C 76 (2016) 155 [arXiv:1512.00815] [INSPIRE].                                                                                                                                                                                                     10
# CMS collaboration, Particle-flow reconstruction and global event description with the CMS detector, 2017 JINST 12 P10003 [arXiv:1706.04965] [INSPIRE].                                                                                                                                                                                                                           10
# CMS collaboration, Jet energy scale and resolution in the CMS experiment in pp collisions at 8 TeV, 2017 JINST 12 P02014 [arXiv:1607.03663] [INSPIRE].                                                                                                                                                                                                                            8
# CMS collaboration, The CMS experiment at the CERN LHC, 2008 JINST 3 S08004 [INSPIRE].                                                                                                                                                                                                                                                                                             8
#                                                                                                                                                                                                                                                                                                                                                                                  ..
# García-Triviño, P., Fernández-Ramírez, L.M., Gil-Mena, A.J., Llorens-Iborra, F., García-Vázquez, C.A., Jurado, F., Optimized operation combining costs, efficiency and lifetime of a hybrid renewable energy system with energy storage by battery and hydrogen in grid-connected applications. Int J Hydrogen Energy 41 (2016), 23132–23144, 10.1016/j.ijhydene.2016.09.140.     1
# Tang, R., Wu, Z., Li, X., Optimal operation of photovoltaic/battery/diesel/cold-ironing hybrid energy system for maritime application. Energy 162 (2018), 697–714, 10.1016/j.energy.2018.08.048.                                                                                                                                                                                  1
# Keskin Arabul, F., Arabul, A.Y., Kumru, C.F., Boynuegri, A.R., Providing energy management of a fuel cell–battery–wind turbine–solar panel hybrid off grid smart home system. Int J Hydrogen Energy 42 (2017), 26906–26913, 10.1016/j.ijhydene.2017.02.204.                                                                                                                       1
# Nojavan, S., Majidi, M., Zare, K., Risk-based optimal performance of a PV/fuel cell/battery/grid hybrid energy system using information gap decision theory in the presence of demand response program. Int J Hydrogen Energy 42 (2017), 11857–11867, 10.1016/j.ijhydene.2017.02.147.                                                                                             1
# Liu, B., Gao, H.M., Wang, J.Y., Jeohn, G.H., Cooper, C.L., Hong, J.S., Role of nitric oxide in inflammation-mediated neurodegeneration. Ann N Y Acad Sci. 962 (2002), 318–331.                                                                                                                                                                                                    1
# Name: count, Length: 44973, dtype: int64

# %% [markdown]
# ### Keywords

# %%
keywords_df = df.explode('keywords', ignore_index=True)[['id', 'keywords']]
keywords_df.rename(columns={
    'id': 'paper_id',
    'keywords': 'keyword'
}, inplace=True)
keywords_df
# Out:
#                 paper_id                                            keyword
# 0     2-s2.0-85058392278              {'@_fa': 'true', '$': '2D materials'}
# 1     2-s2.0-85058392278  {'@_fa': 'true', '$': 'graphitic carbon nitride'}
# 2     2-s2.0-85058392278  {'@_fa': 'true', '$': 'heterostructured compos...
# 3     2-s2.0-85058392278        {'@_fa': 'true', '$': 'hydrogen evolution'}
# 4     2-s2.0-85058392278            {'@_fa': 'true', '$': 'photocatalysis'}
# ...                  ...                                                ...
# 4408  2-s2.0-85119492522  {'@_fa': 'true', '$': 'Complete facial nerve t...
# 4409  2-s2.0-85119492522            {'@_fa': 'true', '$': 'Corticosteroid'}
# 4410  2-s2.0-85119492522  {'@_fa': 'true', '$': 'Facial nerve neurorrhap...
# 4411  2-s2.0-85119492522       {'@_fa': 'true', '$': 'Functional recovery'}
# 4412  2-s2.0-85119492522        {'@_fa': 'true', '$': 'Nerve regeneration'}
#
# [4413 rows x 2 columns]

# %%
keywords_df = keywords_df.join(pd.json_normalize(keywords_df["keyword"])).drop(columns=['keyword'])
keywords_df
# Out:
#                 paper_id  @_fa                                  $
# 0     2-s2.0-85058392278  true                       2D materials
# 1     2-s2.0-85058392278  true           graphitic carbon nitride
# 2     2-s2.0-85058392278  true        heterostructured composites
# 3     2-s2.0-85058392278  true                 hydrogen evolution
# 4     2-s2.0-85058392278  true                     photocatalysis
# ...                  ...   ...                                ...
# 4408  2-s2.0-85119492522  true  Complete facial nerve transection
# 4409  2-s2.0-85119492522  true                     Corticosteroid
# 4410  2-s2.0-85119492522  true          Facial nerve neurorrhaphy
# 4411  2-s2.0-85119492522  true                Functional recovery
# 4412  2-s2.0-85119492522  true                 Nerve regeneration
#
# [4413 rows x 3 columns]

# %%
keywords_df = keywords_df.loc[:, ['paper_id', '$']]
keywords_df.rename(columns={
    '$': 'keyword'
}, inplace=True)
keywords_df
# Out:
#                 paper_id                            keyword
# 0     2-s2.0-85058392278                       2D materials
# 1     2-s2.0-85058392278           graphitic carbon nitride
# 2     2-s2.0-85058392278        heterostructured composites
# 3     2-s2.0-85058392278                 hydrogen evolution
# 4     2-s2.0-85058392278                     photocatalysis
# ...                  ...                                ...
# 4408  2-s2.0-85119492522  Complete facial nerve transection
# 4409  2-s2.0-85119492522                     Corticosteroid
# 4410  2-s2.0-85119492522          Facial nerve neurorrhaphy
# 4411  2-s2.0-85119492522                Functional recovery
# 4412  2-s2.0-85119492522                 Nerve regeneration
#
# [4413 rows x 2 columns]

# %%
paper_to_keywords_df = keywords_df

# %%
keywords_df = keywords_df.drop(columns=['paper_id']).drop_duplicates()
keywords_df
# Out:
#                                 keyword
# 0                          2D materials
# 1              graphitic carbon nitride
# 2           heterostructured composites
# 3                    hydrogen evolution
# 4                        photocatalysis
# ...                                 ...
# 4408  Complete facial nerve transection
# 4409                     Corticosteroid
# 4410          Facial nerve neurorrhaphy
# 4411                Functional recovery
# 4412                 Nerve regeneration
#
# [3818 rows x 1 columns]

# %% [markdown]
# ## Buckets (for multiprocessing)

# %%
buckets = {i: [] for i in range(12)}

for path in pathlib.Path("Data 2018-2023/Project").glob("*/*"):
    buckets[path.__hash__() % 12].append(path)

# buckets
